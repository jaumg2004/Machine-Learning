# %%
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input, Flatten, Conv2D, MaxPooling2D
from matplotlib import pyplot as plt
import numpy as np
from sklearn.metrics import accuracy_score, confusion_matrix
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from tensorflow.keras.datasets import cifar10
#       2 from tensorflow.keras.utils import to_categorical
#       3 from tensorflow.keras.models import Sequential
#
# File ~\PycharmProjects\MachineLearning\.venv\Lib\site-packages\keras\_tf_keras\keras\__init__.py:7
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 7 from keras.api import activations
#       8 from keras.api import applications
#       9 from keras.api import callbacks
#
# File ~\PycharmProjects\MachineLearning\.venv\Lib\site-packages\keras\__init__.py:2
#       1 # DO NOT EDIT. Generated by api_gen.sh
# ----> 2 from keras.api import DTypePolicy
#       3 from keras.api import FloatDTypePolicy
#       4 from keras.api import Function
#
# File ~\PycharmProjects\MachineLearning\.venv\Lib\site-packages\keras\api\__init__.py:9
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
#       8 from keras.api import activations
# ----> 9 from keras.api import applications
#      10 from keras.api import backend
#      11 from keras.api import callbacks
#
# File ~\PycharmProjects\MachineLearning\.venv\Lib\site-packages\keras\api\applications\__init__.py:7
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 7 from keras.api.applications import convnext
#       8 from keras.api.applications import densenet
#       9 from keras.api.applications import efficientnet
#
# File ~\PycharmProjects\MachineLearning\.venv\Lib\site-packages\keras\api\applications\convnext\__init__.py:7
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 7 from keras.src.applications.convnext import ConvNeXtBase
#       8 from keras.src.applications.convnext import ConvNeXtLarge
#       9 from keras.src.applications.convnext import ConvNeXtSmall
#
# File ~\PycharmProjects\MachineLearning\.venv\Lib\site-packages\keras\src\applications\convnext.py:3
#       1 import numpy as np
# ----> 3 from keras.src import backend
#       4 from keras.src import initializers
#       5 from keras.src import layers
#
# File ~\PycharmProjects\MachineLearning\.venv\Lib\site-packages\keras\src\__init__.py:13
#      11 from keras.src import regularizers
#      12 from keras.src import utils
# ---> 13 from keras.src import visualization
#      14 from keras.src.backend import KerasTensor
#      15 from keras.src.layers import Input
#
# File ~\PycharmProjects\MachineLearning\.venv\Lib\site-packages\keras\src\visualization\__init__.py:2
#       1 from keras.src.visualization import draw_bounding_boxes
# ----> 2 from keras.src.visualization import plot_image_gallery
#
# File ~\PycharmProjects\MachineLearning\.venv\Lib\site-packages\keras\src\visualization\plot_image_gallery.py:13
#       8 from keras.src.layers.preprocessing.image_preprocessing.base_image_preprocessing_layer import (  # noqa: E501
#       9     BaseImagePreprocessingLayer,
#      10 )
#      12 try:
# ---> 13     import matplotlib.pyplot as plt
#      14 except ImportError:
#      15     plt = None
#
# File ~\PycharmProjects\MachineLearning\.venv\Lib\site-packages\matplotlib\__init__.py:1296
#    1292     rcParams['backend_fallback'] = False
#    1295 if os.environ.get('MPLBACKEND'):
# -> 1296     rcParams['backend'] = os.environ.get('MPLBACKEND')
#    1299 def get_backend(*, auto_select=True):
#    1300     """
#    1301     Return the name of the current backend.
#    1302
#    (...)
#    1320     matplotlib.use
#    1321     """
#
# File ~\PycharmProjects\MachineLearning\.venv\Lib\site-packages\matplotlib\__init__.py:771, in RcParams.__setitem__(self, key, val)
#     769         cval = self.validate[key](val)
#     770     except ValueError as ve:
# --> 771         raise ValueError(f"Key {key}: {ve}") from None
#     772     self._set(key, cval)
#     773 except KeyError as err:
#
# ValueError: Key backend: 'module://matplotlib_inline.backend_inline' is not a valid value for backend; supported values are ['gtk3agg', 'gtk3cairo', 'gtk4agg', 'gtk4cairo', 'macosx', 'nbagg', 'notebook', 'qtagg', 'qtcairo', 'qt5agg', 'qt5cairo', 'tkagg', 'tkcairo', 'webagg', 'wx', 'wxagg', 'wxcairo', 'agg', 'cairo', 'pdf', 'pgf', 'ps', 'svg', 'template']

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %%
image = x_train[1]
plt.imshow(image, interpolation='bicubic')
plt.show()

# %%
y_train

# %%
x_train.shape

# %%
x_train = x_train.astype('float32')/255.0
x_test = x_test.astype('float32')/255.0

# %%
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %%
y_train

# %%
modelo = Sequential()

modelo.add(Input(shape=(32, 32, 3)))
modelo.add(Conv2D(32, (3, 3), padding='same', activation='relu'))
modelo.add(Conv2D(32, (3, 3), activation='relu'))
modelo.add(MaxPooling2D(pool_size=(2, 2)))
modelo.add(Dropout(0.25))

modelo.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
modelo.add(Conv2D(64, (3, 3), activation='relu'))
modelo.add(MaxPooling2D(pool_size=(2, 2)))
modelo.add(Dropout(0.25))

modelo.add(Flatten())
modelo.add(Dense(512, activation='relu'))
modelo.add(Dropout(0.25))
modelo.add(Dense(10, activation='softmax'))

# %%
modelo.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
modelo.fit(x_train, y_train, batch_size=32, epochs=10)

# %%
previsoes = modelo.predict(x_test)
previsoes

# %%
previsoes_classes = np.argmax(previsoes, axis=1)
previsoes_classes

# %%
y_test_classes = np.argmax(y_test, axis=1)
y_test_classes

# %%
accuracy = accuracy_score(y_test_classes, previsoes_classes)
accuracy

# %%
confusion = confusion_matrix(y_test_classes, previsoes_classes)

# %%
confusion
